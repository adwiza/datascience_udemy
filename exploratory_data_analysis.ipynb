# %% [markdown]
# # Exploratory Data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df = pd.read_csv('https://gist.githubusercontent.com/SoumenAtta/e00bd5cb6ed13a983bf48b845325c837/raw/d5e3560b8bfe97ba126b5e94bed4487c2b1ed787/diabetes.csv', names=names, skiprows=1)

# %%
df.head(7)
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1

# %%
df.tail(2)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.dtypes
# Out:
# preg       int64
# plas       int64
# pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
corr = df.corr()

# %%
corr[corr > .4]
# Out:
#            preg      plas  pres      skin      test  mass  pedi       age  \
# preg   1.000000       NaN   NaN       NaN       NaN   NaN   NaN  0.544341
# plas        NaN  1.000000   NaN       NaN       NaN   NaN   NaN       NaN
# pres        NaN       NaN   1.0       NaN       NaN   NaN   NaN       NaN
# skin        NaN       NaN   NaN  1.000000  0.436783   NaN   NaN       NaN
# test        NaN       NaN   NaN  0.436783  1.000000   NaN   NaN       NaN
# mass        NaN       NaN   NaN       NaN       NaN   1.0   NaN       NaN
# pedi        NaN       NaN   NaN       NaN       NaN   NaN   1.0       NaN
# age    0.544341       NaN   NaN       NaN       NaN   NaN   NaN  1.000000
# class       NaN  0.466581   NaN       NaN       NaN   NaN   NaN       NaN
#
#           class
# preg        NaN
# plas   0.466581
# pres        NaN
# skin        NaN
# test        NaN
# mass        NaN
# pedi        NaN
# age         NaN
# class  1.000000

# %%
df.skew()
# Out:
# preg     0.901674
# plas     0.173754
# pres    -1.843608
# skin     0.109372
# test     2.272251
# mass    -0.428982
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %%
df.groupby('class').size()
# Out:
# class
# 0    500
# 1    268
# dtype: int64

# %%
df.groupby('age').size()
# Out:
# age
# 21    63
# 22    72
# 23    38
# 24    46
# 25    48
# 26    33
# 27    32
# 28    35
# 29    29
# 30    21
# 31    24
# 32    16
# 33    17
# 34    14
# 35    10
# 36    16
# 37    19
# 38    16
# 39    12
# 40    13
# 41    22
# 42    18
# 43    13
# 44     8
# 45    15
# 46    13
# 47     6
# 48     5
# 49     5
# 50     8
# 51     8
# 52     8
# 53     5
# 54     6
# 55     4
# 56     3
# 57     5
# 58     7
# 59     3
# 60     5
# 61     2
# 62     4
# 63     4
# 64     1
# 65     3
# 66     4
# 67     3
# 68     1
# 69     2
# 70     1
# 72     1
# 81     1
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
df.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(10, 7));

# %%
df.hist(figsize=(10, 7));

# %%
df.plot(kind='line', subplots=True, layout=(3, 3), figsize=(10, 7));

# %%
df.preg.plot(kind='line', figsize=(10, 7));

# %%
df.plot(kind='box', subplots=True, layout=(3, 3), figsize=(10, 7));

# %%
import seaborn as sns

# %%
corr = df.corr()

# %%
sns.heatmap(corr);

# %%
sns.barplot(data=df, x='class', y='preg')
# Out:
# <AxesSubplot: xlabel='class', ylabel='preg'>

# %%
df[df['class'] == 0]['preg'].mean()
# Out:
# 3.298
